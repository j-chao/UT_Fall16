# %%
print ('hello world!')
# Out:
# hello world!

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate

array = np.loadtxt('/Users/JCHAO/Documents/UT/YEAR6/ISP/HW/hw6/contourData.dat.txt')

CS = plt.contourf(array)
                 
plt.clim(0,4)

plt.colorbar()
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
